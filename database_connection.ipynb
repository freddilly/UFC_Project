# %%
pip install ipython-sql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
from sqlalchemy import create_engine

# %%
# database connection string
# %sql postgresql://postgres:Randomword76!@localhost/ufc_project_provisional

# %%
engine = create_engine('postgresql://postgres:Randomword76!@localhost/ufc_project_provisional')

# %%
# %%sql
#
# SELECT *
# FROM
#     ufc_fight_data_pre
# LIMIT 3
# Out:
#  * postgresql://postgres:***@localhost/ufc_project_provisional
# 3 rows affected.
# [('Henry Cejudo', 'Marlon Moraes', 'Red', 5, 0, 4, 1, 4, 'Orthodox', Decimal('167.64'), Decimal('170.18'), 0, 4, 2, 8, 'Orthodox', Decimal('162.56'), Decimal('162.56'), 31, 32),
#  ('Valentina Shevchenko', 'Jessica Eye', 'Red', 5, 0, 3, 6, 4, 'Orthodox', Decimal('167.64'), Decimal('167.64'), 0, 2, 2, 5, 'Southpaw', Decimal('165.1'), Decimal('167.64'), 32, 31),
#  ('Tony Ferguson', 'Donald Cerrone', 'Red', 3, 0, 3, 8, 23, 'Orthodox', Decimal('185.42'), Decimal('185.42'), 0, 11, 1, 14, 'Orthodox', Decimal('180.34'), Decimal('193.04'), 36, 35)]

# %%
import pandas as pd
fight_data_df = pd.read_sql('SELECT * FROM ufc_fight_data_pre',engine)

# %%
fight_data_df.head()
# Out:
#             red_fighter    blue_fighter winner  no_of_rounds  \
# 0          Henry Cejudo   Marlon Moraes    Red             5
# 1  Valentina Shevchenko     Jessica Eye    Red             5
# 2         Tony Ferguson  Donald Cerrone    Red             3
# 3         Jimmie Rivera        Petr Yan   Blue             3
# 4           Tai Tuivasa   Blagoy Ivanov   Blue             3
#
#    b_current_lose_streak  b_current_win_streak  b_losses  b_wins  b_stance  \
# 0                      0                     4         1       4  Orthodox
# 1                      0                     3         6       4  Orthodox
# 2                      0                     3         8      23  Orthodox
# 3                      0                     4         0       4    Switch
# 4                      0                     1         1       1  Southpaw
#
#    b_height_cms  b_reach_cms  r_current_lose_streak  r_current_win_streak  \
# ...

# %%
fight_data_df.tail()
# Out:
#          red_fighter   blue_fighter winner  no_of_rounds  \
# 5139  Gerard Gordeau   Kevin Rosier    Red             1
# 5140    Ken Shamrock  Patrick Smith    Red             1
# 5141    Royce Gracie  Art Jimmerson    Red             1
# 5142    Kevin Rosier   Zane Frazier    Red             1
# 5143  Gerard Gordeau     Teila Tuli    Red             1
#
#       b_current_lose_streak  b_current_win_streak  b_losses  b_wins  b_stance  \
# 5139                      0                     1         0       1  Orthodox
# 5140                      0                     0         0       0  Orthodox
# 5141                      0                     0         0       0  Orthodox
# 5142                      0                     0         0       0  Orthodox
# 5143                      0                     0         0       0  Orthodox
#
#       b_height_cms  b_reach_cms  r_current_lose_streak  r_current_win_streak  \
# ...
